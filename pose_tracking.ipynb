# %%
# %pip install opencv-python
# Out:
# Requirement already satisfied: opencv-python in c:\users\jsjas\onedrive\documents\cobacobs\pose tracking\venv\lib\site-packages (4.8.1.78)
# Requirement already satisfied: numpy>=1.19.3 in c:\users\jsjas\onedrive\documents\cobacobs\pose tracking\venv\lib\site-packages (from opencv-python) (1.26.2)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 22.0.4; however, version 23.3.1 is available.
# You should consider upgrading via the 'c:\Users\jsjas\OneDrive\Documents\cobacobs\pose tracking\venv\Scripts\python.exe -m pip install --upgrade pip' command.

# %%
# %pip install mediapipe
# Out:
# Requirement already satisfied: mediapipe in c:\users\jsjas\onedrive\documents\cobacobs\pose tracking\venv\lib\site-packages (0.10.8)
# Requirement already satisfied: numpy in c:\users\jsjas\onedrive\documents\cobacobs\pose tracking\venv\lib\site-packages (from mediapipe) (1.26.2)
# Requirement already satisfied: matplotlib in c:\users\jsjas\onedrive\documents\cobacobs\pose tracking\venv\lib\site-packages (from mediapipe) (3.8.2)
# Requirement already satisfied: absl-py in c:\users\jsjas\onedrive\documents\cobacobs\pose tracking\venv\lib\site-packages (from mediapipe) (2.0.0)
# Requirement already satisfied: protobuf<4,>=3.11 in c:\users\jsjas\onedrive\documents\cobacobs\pose tracking\venv\lib\site-packages (from mediapipe) (3.20.3)
# Requirement already satisfied: flatbuffers>=2.0 in c:\users\jsjas\onedrive\documents\cobacobs\pose tracking\venv\lib\site-packages (from mediapipe) (23.5.26)
# Requirement already satisfied: attrs>=19.1.0 in c:\users\jsjas\onedrive\documents\cobacobs\pose tracking\venv\lib\site-packages (from mediapipe) (23.1.0)
# Requirement already satisfied: sounddevice>=0.4.4 in c:\users\jsjas\onedrive\documents\cobacobs\pose tracking\venv\lib\site-packages (from mediapipe) (0.4.6)
# Requirement already satisfied: opencv-contrib-python in c:\users\jsjas\onedrive\documents\cobacobs\pose tracking\venv\lib\site-packages (from mediapipe) (4.8.1.78)
# Requirement already satisfied: CFFI>=1.0 in c:\users\jsjas\onedrive\documents\cobacobs\pose tracking\venv\lib\site-packages (from sounddevice>=0.4.4->mediapipe) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\jsjas\onedrive\documents\cobacobs\pose tracking\venv\lib\site-packages (from matplotlib->mediapipe) (2.8.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\jsjas\onedrive\documents\cobacobs\pose tracking\venv\lib\site-packages (from matplotlib->mediapipe) (0.12.1)
# Requirement already satisfied: pillow>=8 in c:\users\jsjas\onedrive\documents\cobacobs\pose tracking\venv\lib\site-packages (from matplotlib->mediapipe) (10.1.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\jsjas\onedrive\documents\cobacobs\pose tracking\venv\lib\site-packages (from matplotlib->mediapipe) (1.4.5)
# Requirement already satisfied: importlib-resources>=3.2.0 in c:\users\jsjas\onedrive\documents\cobacobs\pose tracking\venv\lib\site-packages (from matplotlib->mediapipe) (6.1.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\jsjas\onedrive\documents\cobacobs\pose tracking\venv\lib\site-packages (from matplotlib->mediapipe) (1.2.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\jsjas\onedrive\documents\cobacobs\pose tracking\venv\lib\site-packages (from matplotlib->mediapipe) (23.2)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\jsjas\onedrive\documents\cobacobs\pose tracking\venv\lib\site-packages (from matplotlib->mediapipe) (4.46.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\jsjas\onedrive\documents\cobacobs\pose tracking\venv\lib\site-packages (from matplotlib->mediapipe) (3.1.1)
# Requirement already satisfied: pycparser in c:\users\jsjas\onedrive\documents\cobacobs\pose tracking\venv\lib\site-packages (from CFFI>=1.0->sounddevice>=0.4.4->mediapipe) (2.21)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\jsjas\onedrive\documents\cobacobs\pose tracking\venv\lib\site-packages (from importlib-resources>=3.2.0->matplotlib->mediapipe) (3.17.0)
# Requirement already satisfied: six>=1.5 in c:\users\jsjas\onedrive\documents\cobacobs\pose tracking\venv\lib\site-packages (from python-dateutil>=2.7->matplotlib->mediapipe) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 22.0.4; however, version 23.3.1 is available.
# You should consider upgrading via the 'c:\Users\jsjas\OneDrive\Documents\cobacobs\pose tracking\venv\Scripts\python.exe -m pip install --upgrade pip' command.

# %%
import cv2
import mediapipe as mp
import numpy as np

# %%
## initialize pose estimator
mp_drawing = mp.solutions.drawing_utils
mp_pose = mp.solutions.pose
pose = mp_pose.Pose()

# %%
def overlay_image (base_img, overlay_img, x_offset=0, y_offset=0):
    # border_size = 400
    border_size = 400

    height, width, channels = base_img.shape

    # overlay_img_size = int(width*40/100)
    overlay_img_size = int(width*100/100)

    base_img = cv2.copyMakeBorder(
        base_img,
        top=border_size,
        bottom=border_size,
        left=border_size,
        right=border_size,
        borderType=cv2.BORDER_CONSTANT,
        value=(0, 0, 255)
    )

    x_offset += border_size
    y_offset += border_size
    

    print(base_img.shape)

    overlay_img = cv2.resize(overlay_img, (overlay_img_size, overlay_img_size))

    y1, y2 = y_offset - int(overlay_img.shape[0]/2), y_offset + int(overlay_img.shape[0]/2)
    x1, x2 = x_offset - int(overlay_img.shape[1]/2), x_offset + int(overlay_img.shape[1]/2)


    alpha_s = overlay_img[:, :, 3] / 255.0 if overlay_img.shape[2] == 4 else 1.0
    alpha_l = 1.0 - alpha_s

    for c in range(0, 3):
        base_img[y1:y2, x1:x2, c] = (alpha_s * overlay_img[:, :, c] +
                                  alpha_l * base_img[y1:y2, x1:x2, c])
        
    base_img = base_img[border_size:-border_size, border_size:-border_size]
    
    return base_img

# %%
class Animation():
    def __init__(self, prefix, offset_x, offset_y, frame=2) -> None:
        self.prefix = prefix
        self.offset_x = offset_x
        self.offset_y = offset_y
        self.current_iteration = 1
        self.current_frame = 0
        self.frame = frame
    
    def get_image(self):
        return cv2.imread(f"{self.prefix}{self.current_iteration}.png", cv2.IMREAD_UNCHANGED)

    def fetch_next_iteration(self):
        self.current_frame += 1
        if self.current_frame == self.frame:
            self.current_frame = 0
            self.current_iteration += 1
        return self.get_image()
    
    def apply_overlay_image(self, base_img):
        image = self.fetch_next_iteration()

        print(self.current_iteration)

        if image is not None:
            return overlay_image(base_img, image, self.offset_x, self.offset_y)
        else:
            return None

# %%
animation_queue = []


# Load the video
video_path = "lv_0_20231028162427.mp4"
cap = cv2.VideoCapture(video_path)
input_fps = cap.get(cv2.CAP_PROP_FPS)

# Check if the video opened successfully
if not cap.isOpened():
    print("Error opening video file.")
    exit()

# Create a VideoWriter object to save the output
output_path = "output_video.mp4"
fourcc = cv2.VideoWriter_fourcc(*'mp4v')
out = cv2.VideoWriter(output_path, fourcc, input_fps, (350, 600))  # Adjust the resolution as needed

# Load the smaller image
small_image = cv2.imread("animations\step1\placeholder1.png", cv2.IMREAD_UNCHANGED)

# Process each frame in the video
while True:
    ret, frame = cap.read()

    # Break the loop if the video is finished
    if not ret:
        break

    frame = cv2.resize(frame, (350, 600))

    # Convert the frame to RGB
    frame_rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)

    # Process the frame with MediaPipe Pose
    pose_results = pose.process(frame_rgb)

    next_queue = []
    for animation in animation_queue:
        image = animation.apply_overlay_image(frame)
        if image is not None:
            frame = image
            next_queue.append(animation)
    
    animation_queue = next_queue

    # Write the frame to the output video
    out.write(frame)

    # Display the frame
    cv2.imshow("Overlay Result", frame)

    # Break the loop if the 'q' key is pressed
    key = cv2.waitKey(20)

    if key == ord('q'):
        break

    if key == ord('a'):
        if pose_results.pose_landmarks:
            left_foot = pose_results.pose_landmarks.landmark[27] if pose_results.pose_landmarks.landmark[31].visibility > 0.1 else None
            h, w, _ = frame.shape
            left_foot_x, left_foot_y = int(left_foot.x * w), int(left_foot.y * h)
            right_foot_x, right_foot_y = int(right_foot.x * w), int(right_foot.y * h)
            
            animation_queue.append(Animation("animations/step1/step", left_foot_x + 20, left_foot_y - 50))
    
    if key == ord('s'):
        if pose_results.pose_landmarks:
            right_foot = pose_results.pose_landmarks.landmark[28] if pose_results.pose_landmarks.landmark[32].visibility > 0.1 else None
            h, w, _ = frame.shape
            right_foot_x, right_foot_y = int(right_foot.x * w), int(right_foot.y * h)
            
            animation_queue.append(Animation("animations/step1/step", right_foot_x - 20, right_foot_y - 50))
    
    print(animation_queue)

# Release video capture and writer objects
cap.release()
out.release()

# Close all OpenCV windows
cv2.destroyAllWindows()
# Out:
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# [<__main__.Animation object at 0x0000020ED0C1ABE0>]
# 1
# (1400, 1150, 3)
# [<__main__.Animation object at 0x0000020ED0C1ABE0>]
# 2
# (1400, 1150, 3)
# [<__main__.Animation object at 0x0000020ED0C1ABE0>]
# 2
# (1400, 1150, 3)
# [<__main__.Animation object at 0x0000020ED0C1ABE0>]
# 3
# (1400, 1150, 3)
# [<__main__.Animation object at 0x0000020ED0C1ABE0>]
# 3
# (1400, 1150, 3)
# [<__main__.Animation object at 0x0000020ED0C1ABE0>]
# 4
# (1400, 1150, 3)
# [<__main__.Animation object at 0x0000020ED0C1ABE0>]
# 4
# (1400, 1150, 3)
# [<__main__.Animation object at 0x0000020ED0C1ABE0>]
# 5
# []
# []
# [<__main__.Animation object at 0x0000020ED28A6670>]
# 1
# (1400, 1150, 3)
# [<__main__.Animation object at 0x0000020ED28A6670>]
# 2
# (1400, 1150, 3)
# [<__main__.Animation object at 0x0000020ED28A6670>]
# 2
# (1400, 1150, 3)
# [<__main__.Animation object at 0x0000020ED28A6670>]
# 3
# (1400, 1150, 3)
# [<__main__.Animation object at 0x0000020ED28A6670>]
# 3
# (1400, 1150, 3)
# [<__main__.Animation object at 0x0000020ED28A6670>]
# 4
# (1400, 1150, 3)
# [<__main__.Animation object at 0x0000020ED28A6670>]
# 4
# (1400, 1150, 3)
# [<__main__.Animation object at 0x0000020ED28A6670>]
# 5
# []
# []
# []
# []
# []
# [<__main__.Animation object at 0x0000020ED288DDC0>]
# 1
# (1400, 1150, 3)
# [<__main__.Animation object at 0x0000020ED288DDC0>]
# 2
# (1400, 1150, 3)
# [<__main__.Animation object at 0x0000020ED288DDC0>]
# 2
# (1400, 1150, 3)
# [<__main__.Animation object at 0x0000020ED288DDC0>]
# 3
# (1400, 1150, 3)
# [<__main__.Animation object at 0x0000020ED288DDC0>]
# 3
# (1400, 1150, 3)
# [<__main__.Animation object at 0x0000020ED288DDC0>]
# 4
# (1400, 1150, 3)
# [<__main__.Animation object at 0x0000020ED288DDC0>]
# 4
# (1400, 1150, 3)
# [<__main__.Animation object at 0x0000020ED288DDC0>]
# 5
# []
# []
# []
# []
# []
# []
# [<__main__.Animation object at 0x0000020ED2890A30>]
# 1
# (1400, 1150, 3)
# [<__main__.Animation object at 0x0000020ED2890A30>]
# 2
# (1400, 1150, 3)
# [<__main__.Animation object at 0x0000020ED2890A30>]
# 2
# (1400, 1150, 3)
# [<__main__.Animation object at 0x0000020ED2890A30>]
# 3
# (1400, 1150, 3)
# [<__main__.Animation object at 0x0000020ED2890A30>]
# 3
# (1400, 1150, 3)
# [<__main__.Animation object at 0x0000020ED2890A30>]
# 4
# (1400, 1150, 3)
# [<__main__.Animation object at 0x0000020ED2890A30>]
# 4
# (1400, 1150, 3)
# [<__main__.Animation object at 0x0000020ED2890A30>]
# 5
# []
# []
# []
# []
# []
# []
# []
# [<__main__.Animation object at 0x0000020ED239B910>]
# 1
# (1400, 1150, 3)
# [<__main__.Animation object at 0x0000020ED239B910>]
# 2
# (1400, 1150, 3)
# [<__main__.Animation object at 0x0000020ED239B910>]
# 2
# (1400, 1150, 3)
# [<__main__.Animation object at 0x0000020ED239B910>]
# 3
# (1400, 1150, 3)
# [<__main__.Animation object at 0x0000020ED239B910>]
# 3
# (1400, 1150, 3)
# [<__main__.Animation object at 0x0000020ED239B910>]
# 4
# (1400, 1150, 3)
# [<__main__.Animation object at 0x0000020ED239B910>]
# 4
# (1400, 1150, 3)
# [<__main__.Animation object at 0x0000020ED239B910>]
# 5
# []
# []
# []
# []
# []
# []
# []
# []
# [<__main__.Animation object at 0x0000020ED2890C70>]
# 1
# (1400, 1150, 3)
# [<__main__.Animation object at 0x0000020ED2890C70>]
# 2
# (1400, 1150, 3)
# [<__main__.Animation object at 0x0000020ED2890C70>]
# 2
# (1400, 1150, 3)
# [<__main__.Animation object at 0x0000020ED2890C70>]
# 3
# (1400, 1150, 3)
# [<__main__.Animation object at 0x0000020ED2890C70>]
# 3
# (1400, 1150, 3)
# [<__main__.Animation object at 0x0000020ED2890C70>]
# 4
# (1400, 1150, 3)
# [<__main__.Animation object at 0x0000020ED2890C70>]
# 4
# (1400, 1150, 3)
# [<__main__.Animation object at 0x0000020ED2890C70>]
# 5
# []
# []
# [<__main__.Animation object at 0x0000020ED28A6C70>]
# 1
# (1400, 1150, 3)
# [<__main__.Animation object at 0x0000020ED28A6C70>]
# 2
# (1400, 1150, 3)
# [<__main__.Animation object at 0x0000020ED28A6C70>]
# 2
# (1400, 1150, 3)
# [<__main__.Animation object at 0x0000020ED28A6C70>]
# 3
# (1400, 1150, 3)
# [<__main__.Animation object at 0x0000020ED28A6C70>]
# 3
# (1400, 1150, 3)
# [<__main__.Animation object at 0x0000020ED28A6C70>]
# 4
# (1400, 1150, 3)
# [<__main__.Animation object at 0x0000020ED28A6C70>]
# 4
# (1400, 1150, 3)
# [<__main__.Animation object at 0x0000020ED28A6C70>]
# 5
# []
# []
# []
# []
# []
# []
# []
# []
# [<__main__.Animation object at 0x0000020EB9F3DDC0>]
# 1
# (1400, 1150, 3)
# [<__main__.Animation object at 0x0000020EB9F3DDC0>]
# 2
# (1400, 1150, 3)
# [<__main__.Animation object at 0x0000020EB9F3DDC0>]
# 2
# (1400, 1150, 3)
# [<__main__.Animation object at 0x0000020EB9F3DDC0>]
# 3
# (1400, 1150, 3)
# [<__main__.Animation object at 0x0000020EB9F3DDC0>]
# 3
# (1400, 1150, 3)
# [<__main__.Animation object at 0x0000020EB9F3DDC0>]
# 4
# (1400, 1150, 3)
# [<__main__.Animation object at 0x0000020EB9F3DDC0>]
# 4
# (1400, 1150, 3)
# [<__main__.Animation object at 0x0000020EB9F3DDC0>]
# 5
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
